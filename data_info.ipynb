# %% [markdown]
# <a href="https://colab.research.google.com/github/xXAI-botXx/Weather-Analysis/blob/main/data_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use this command to load the data

# %%
# !git clone https://github.com/xXAI-botXx/DATA.git
# Out:
# Cloning into 'DATA'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# Access data:

# %% [markdown]
# You have to connect your GitHub Acc and check the Private Repo box.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
